# %%
import matplotlib.pyplot as plt

# %%
# Autoreload src when changed
# %load_ext autoreload
# %autoreload 2

# %%
# Updates the catalog/context/session/pipelines variables if changed <-- run this if e.g. catalog or pipelines was edited since starting the notebook
# %reload_kedro
# Out:
# [03/20/23 21:15:41] INFO     Resolved project path as: /home/zhixingruan/Projects/popsign-meow.     ]8;id=638218;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=611279;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/20/23 21:15:41] INFO     Kedro project popsign-meow                                             ]8;id=828843;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=929395;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/ipython/__init__.py#103\103]8;;\
# ...

# %%
train_info = catalog.load('signs')
train_info
# Out:
# [03/20/23 21:19:49] INFO     Loading data from 'signs' (CSVDataSet)...                          ]8;id=802689;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=632869;file:///home/zhixingruan/miniconda3/envs/popsign-meow/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                                                 path  participant_id  \
# 0      train_landmark_files/26734/1000035562.parquet           26734
# 1      train_landmark_files/28656/1000106739.parquet           28656
# 2       train_landmark_files/16069/100015657.parquet           16069
# 3      train_landmark_files/25571/1000210073.parquet           25571
# 4      train_landmark_files/62590/1000240708.parquet           62590
# ...                                              ...             ...
# 94472   train_landmark_files/53618/999786174.parquet           53618
# ...

# %%
train_info.sign.value_counts().plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: >

# %%
print('mean of the train samples for each sign: ', train_info.sign.value_counts().mean())
print('maximun of the train samples for each sign: ', train_info.sign.value_counts().max())
print('minimun of the train samples for each sign: ', train_info.sign.value_counts().min())
# Out:
# mean of the train samples for each sign:  377.908
# maximun of the train samples for each sign:  415
# minimun of the train samples for each sign:  299

# %%
check = train_info.loc[train_info.participant_id == 16069]

# %%
check.sign.value_counts()
# Out:
# cereal    27
# on        26
# talk      25
# close     25
# pen       25
#           ..
# before    13
# person    13
# zipper    11
# beside    11
# jacket     9
# Name: sign, Length: 250, dtype: int64
